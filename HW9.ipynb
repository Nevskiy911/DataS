# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from keras.utils import plot_model
from keras.datasets import fashion_mnist

import numpy as np
import matplotlib.pyplot as plt

from IPython.display import clear_output, display, Math
from tensorflow.keras.activations import linear, sigmoid, tanh, relu
from tensorflow.keras.layers import LeakyReLU, ELU

# %% [markdown]
# #Завантажуємо датасет, розділяємо його на тестові та навчальні вибірки, створюємо константи та візуалізуємо початкові дані

# %%
class_labels = {0: 'T-shirt/top', 1: 'Trouser', 2: 'Pullover', 3: 'Dress',
                4: 'Coat', 5: 'Sandal', 6: 'Shirt', 7: 'Sneaker', 8: 'Bag', 9: 'Ankle boot'}
input_shape = (28, 28, 1)
num_classes = 10

# %%
# Завантажуємо датасет і розділимо його на навчальну та тестову вибірки.
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Перетворюємо цілочисельні пікселі на тип float32
x_train, x_test = np.array(x_train, np.float32), np.array(x_test, np.float32)

# Нормалізуємо значення пікселів, розділивши яскравість кожного пікселя на 255.
x_train, x_test = x_train / 255., x_test / 255.
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
number_of_images = 40
f, ax = plt.subplots(5, 8, figsize=(12, 8))

for i, sample_index in enumerate(np.random.randint(1, x_test.shape[0], number_of_images)):
    test_image = x_test[sample_index].reshape(1, -1)
    test_item = y_test[sample_index]
    ax[i//8, i % 8].imshow(test_image[0].reshape((28, 28)))
    ax[i//8, i % 8].axis('off')
    ax[i//8, i %
        8].set_title(f"{class_labels.get(test_item)}", fontsize=8)
plt.show()

# %% [markdown]
# #Будуємо архітектуру мережі

# %%
# За допомогою TensorFlow побудуємо графіки функції активації

x = np.linspace(-5, 5, 100)
x_tensor = tf.convert_to_tensor(x, dtype=tf.float32)

activation_functions = [linear, sigmoid, tanh, relu, LeakyReLU(alpha=0.1), ELU(alpha=1.0)]
activation_names = ['Linear', 'Sigmoid', 'tanh', 'ReLU', 'Leaky ReLU', 'ELU']
analitic = [r'$x$', r'$\frac{1}{1 + e^{-x}}$', r'$\tanh$', r'$\max(0, x)$', r'$\max(\alpha\cdot x, x)$', r'$x$, $x \geq 0$; $\alpha\cdot(e^x - 1)$, $x < 0$']


plt.figure(figsize=(16, 16))

for i in range(len(activation_functions)):
    activation_name = activation_names[i]

    plt.subplot(6, 6, i + 1)
    plt.plot(x, activation_functions[i](x_tensor).numpy(), label=r'$f(x)$')
    plt.title(f'{activation_name}: {analitic[i]}')

    with tf.GradientTape() as tape:
        tape.watch(x_tensor)
        y = activation_functions[i](x_tensor)
    derivative = tape.gradient(y, x_tensor).numpy()
    plt.plot(x, derivative, label=r'$\frac{df(x)}{dx}$')
    plt.legend()

plt.tight_layout()
plt.show()

# %%
# Побудова архітектури моделі
keras.utils.set_random_seed(42)

def build_model(learning_rate, l2_parameter):
    model = keras.Sequential()
    model.add(layers.Flatten(input_shape=(28, 28, 1)))
    model.add(layers.Dense(128, activation='relu',
        kernel_regularizer=regularizers.l2(l2_parameter)))
    model.add(layers.Dropout(0.25))
    model.add(layers.Dense(64, activation='relu',
        kernel_regularizer=regularizers.l2(l2_parameter)))
    model.add(layers.Dropout(0.1))
    model.add(layers.Dense(10, activation='softmax'))

    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'],
                  )
    return model

# %% [markdown]
# ## Підбір гіперпараметрів

# %%
epochs = 30
steps_per_epoch = 1_000
batch_size = 2 * 64
l2_parameter = 1e-4
learning_rate = 1e-3

# %%
epochs = 50
steps_per_epoch = 1_000
batch_size = 2 * 64
l2_parameter = 1e-4
learning_rate = 1e-3

# %%
epochs = 50
steps_per_epoch = 5_00
batch_size = 2 * 64
l2_parameter = 1e-4
learning_rate = 1e-3

# %%
epochs = 70
steps_per_epoch = 5_00
batch_size = 2 * 64
l2_parameter = 1e-4
learning_rate = 1e-3

# %%
epochs = 70
steps_per_epoch = 1_000
batch_size = 2 * 64
#l2_parameter = 1e-4
learning_rate = 1e-3

# %%
epochs = 50
steps_per_epoch = 1_000
batch_size = 2 * 32
#l2_parameter = 1e-4
learning_rate = 1e-5

# %%
epochs = 50
steps_per_epoch = 1_000
batch_size = 2 * 32
#l2_parameter = 1e-4
learning_rate = 1e-3

# %%
#Кращий
epochs = 75
steps_per_epoch = 1_000
batch_size = 2 * 128
#l2_parameter = 1e-4
learning_rate = 1e-3

# %%
epochs = 95
steps_per_epoch = 1_000
batch_size = 2 * 128
#l2_parameter = 1e-4
learning_rate = 1e-2

# %%
#Ще кращий
epochs = 75
steps_per_epoch = 1_000
batch_size = 2 * 256
#l2_parameter = 1e-4
learning_rate = 1e-3

# %%
epochs = 75
steps_per_epoch = 5_000
batch_size = 2 * 512
#l2_parameter = 1e-4
learning_rate = 1e-3

# %%
epochs = 55
steps_per_epoch = 5_000
batch_size = 2 * 1024
#l2_parameter = 1e-4
learning_rate = 1e-2

# %%
epochs = 75
steps_per_epoch = 5_000
batch_size = 2 * 16
#l2_parameter = 1e-4
learning_rate = 1e-3

# %%
#Найкращий
epochs = 75
steps_per_epoch = 5_00
batch_size = 2 * 256
#l2_parameter = 1e-4
learning_rate = 1e-3

# %%
epochs = 75
steps_per_epoch = 3_0
batch_size = 2 * 256
#l2_parameter = 1e-4
learning_rate = 1e-4

# %% [markdown]
# ## Створення моделі

# %%
model = build_model(learning_rate, l2_parameter)
model.summary()
# Out:
# Model: "sequential_28"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_28 (Flatten)        (None, 784)               0
#
#  dense_84 (Dense)            (None, 128)               100480
#
#  dropout_56 (Dropout)        (None, 128)               0
#
#  dense_85 (Dense)            (None, 64)                8256
#
#  dropout_57 (Dropout)        (None, 64)                0
#
#  dense_86 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 109386 (427.29 KB)
# Trainable params: 109386 (427.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Навчання моделі

# %%
# Перемішаємо тренувальні дані
train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_data = train_data.repeat().shuffle(5000).batch(256).prefetch(1)


# Навчання моделі
history = model.fit(
    x_train, y_train,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=(x_test, y_test)
)

# Оцінка моделі на тестовому наборі даних
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=1)
print(f'\nТочність на тестовому наборі: {test_accuracy:.2f}')
# Out:
# Epoch 1/75
# 118/118 [==============================] - 2s 13ms/step - loss: 0.8724 - accuracy: 0.7018 - val_loss: 0.5482 - val_accuracy: 0.8178
# Epoch 2/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.5340 - accuracy: 0.8243 - val_loss: 0.4752 - val_accuracy: 0.8426
# Epoch 3/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.4685 - accuracy: 0.8446 - val_loss: 0.4451 - val_accuracy: 0.8524
# Epoch 4/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.4428 - accuracy: 0.8536 - val_loss: 0.4358 - val_accuracy: 0.8538
# Epoch 5/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.4205 - accuracy: 0.8613 - val_loss: 0.4196 - val_accuracy: 0.8611
# Epoch 6/75
# 118/118 [==============================] - 1s 12ms/step - loss: 0.4041 - accuracy: 0.8667 - val_loss: 0.3988 - val_accuracy: 0.8700
# Epoch 7/75
# 118/118 [==============================] - 2s 13ms/step - loss: 0.3936 - accuracy: 0.8697 - val_loss: 0.4087 - val_accuracy: 0.8647
# Epoch 8/75
# 118/118 [==============================] - 2s 17ms/step - loss: 0.3857 - accuracy: 0.8731 - val_loss: 0.3890 - val_accuracy: 0.8749
# Epoch 9/75
# 118/118 [==============================] - 2s 15ms/step - loss: 0.3734 - accuracy: 0.8776 - val_loss: 0.3977 - val_accuracy: 0.8706
# Epoch 10/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3693 - accuracy: 0.8775 - val_loss: 0.3769 - val_accuracy: 0.8775
# Epoch 11/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3603 - accuracy: 0.8821 - val_loss: 0.3792 - val_accuracy: 0.8771
# Epoch 12/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3537 - accuracy: 0.8836 - val_loss: 0.3779 - val_accuracy: 0.8800
# Epoch 13/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3517 - accuracy: 0.8841 - val_loss: 0.3731 - val_accuracy: 0.8800
# Epoch 14/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3482 - accuracy: 0.8863 - val_loss: 0.3696 - val_accuracy: 0.8797
# Epoch 15/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3458 - accuracy: 0.8866 - val_loss: 0.3698 - val_accuracy: 0.8799
# Epoch 16/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3392 - accuracy: 0.8881 - val_loss: 0.3698 - val_accuracy: 0.8793
# Epoch 17/75
# 118/118 [==============================] - 2s 14ms/step - loss: 0.3377 - accuracy: 0.8907 - val_loss: 0.3696 - val_accuracy: 0.8814
# Epoch 18/75
# 118/118 [==============================] - 2s 17ms/step - loss: 0.3323 - accuracy: 0.8923 - val_loss: 0.3593 - val_accuracy: 0.8862
# Epoch 19/75
# 118/118 [==============================] - 2s 13ms/step - loss: 0.3256 - accuracy: 0.8931 - val_loss: 0.3710 - val_accuracy: 0.8802
# Epoch 20/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3248 - accuracy: 0.8947 - val_loss: 0.3670 - val_accuracy: 0.8822
# Epoch 21/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3184 - accuracy: 0.8969 - val_loss: 0.3575 - val_accuracy: 0.8872
# Epoch 22/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3208 - accuracy: 0.8966 - val_loss: 0.3597 - val_accuracy: 0.8842
# Epoch 23/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3176 - accuracy: 0.8970 - val_loss: 0.3600 - val_accuracy: 0.8832
# Epoch 24/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3182 - accuracy: 0.8974 - val_loss: 0.3676 - val_accuracy: 0.8808
# Epoch 25/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3137 - accuracy: 0.8985 - val_loss: 0.3663 - val_accuracy: 0.8849
# Epoch 26/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3114 - accuracy: 0.8997 - val_loss: 0.3619 - val_accuracy: 0.8865
# Epoch 27/75
# 118/118 [==============================] - 2s 17ms/step - loss: 0.3104 - accuracy: 0.9000 - val_loss: 0.3529 - val_accuracy: 0.8871
# Epoch 28/75
# 118/118 [==============================] - 2s 17ms/step - loss: 0.3018 - accuracy: 0.9023 - val_loss: 0.3674 - val_accuracy: 0.8821
# Epoch 29/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3003 - accuracy: 0.9050 - val_loss: 0.3615 - val_accuracy: 0.8857
# Epoch 30/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2999 - accuracy: 0.9045 - val_loss: 0.3575 - val_accuracy: 0.8885
# Epoch 31/75
# 118/118 [==============================] - 2s 14ms/step - loss: 0.2961 - accuracy: 0.9057 - val_loss: 0.3558 - val_accuracy: 0.8912
# Epoch 32/75
# 118/118 [==============================] - 2s 17ms/step - loss: 0.2943 - accuracy: 0.9050 - val_loss: 0.3598 - val_accuracy: 0.8867
# Epoch 33/75
# 118/118 [==============================] - 2s 17ms/step - loss: 0.2941 - accuracy: 0.9075 - val_loss: 0.3543 - val_accuracy: 0.8896
# Epoch 34/75
# 118/118 [==============================] - 2s 18ms/step - loss: 0.2961 - accuracy: 0.9058 - val_loss: 0.3581 - val_accuracy: 0.8884
# Epoch 35/75
# 118/118 [==============================] - 2s 20ms/step - loss: 0.2896 - accuracy: 0.9095 - val_loss: 0.3596 - val_accuracy: 0.8847
# Epoch 36/75
# 118/118 [==============================] - 2s 20ms/step - loss: 0.2906 - accuracy: 0.9081 - val_loss: 0.3485 - val_accuracy: 0.8943
# Epoch 37/75
# 118/118 [==============================] - 2s 21ms/step - loss: 0.2905 - accuracy: 0.9075 - val_loss: 0.3558 - val_accuracy: 0.8869
# Epoch 38/75
# 118/118 [==============================] - 2s 17ms/step - loss: 0.2871 - accuracy: 0.9086 - val_loss: 0.3521 - val_accuracy: 0.8895
# Epoch 39/75
# 118/118 [==============================] - 2s 17ms/step - loss: 0.2861 - accuracy: 0.9089 - val_loss: 0.3513 - val_accuracy: 0.8913
# Epoch 40/75
# 118/118 [==============================] - 2s 14ms/step - loss: 0.2824 - accuracy: 0.9114 - val_loss: 0.3544 - val_accuracy: 0.8920
# Epoch 41/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2849 - accuracy: 0.9097 - val_loss: 0.3572 - val_accuracy: 0.8897
# Epoch 42/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2808 - accuracy: 0.9099 - val_loss: 0.3576 - val_accuracy: 0.8921
# Epoch 43/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2792 - accuracy: 0.9120 - val_loss: 0.3540 - val_accuracy: 0.8906
# Epoch 44/75
# 118/118 [==============================] - 2s 18ms/step - loss: 0.2807 - accuracy: 0.9121 - val_loss: 0.3507 - val_accuracy: 0.8952
# Epoch 45/75
# 118/118 [==============================] - 2s 16ms/step - loss: 0.2796 - accuracy: 0.9122 - val_loss: 0.3545 - val_accuracy: 0.8917
# Epoch 46/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2786 - accuracy: 0.9122 - val_loss: 0.3544 - val_accuracy: 0.8892
# Epoch 47/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2815 - accuracy: 0.9104 - val_loss: 0.3512 - val_accuracy: 0.8921
# Epoch 48/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2752 - accuracy: 0.9140 - val_loss: 0.3536 - val_accuracy: 0.8913
# Epoch 49/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2732 - accuracy: 0.9143 - val_loss: 0.3633 - val_accuracy: 0.8911
# Epoch 50/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2733 - accuracy: 0.9147 - val_loss: 0.3515 - val_accuracy: 0.8904
# Epoch 51/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2732 - accuracy: 0.9136 - val_loss: 0.3616 - val_accuracy: 0.8928
# Epoch 52/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2721 - accuracy: 0.9147 - val_loss: 0.3550 - val_accuracy: 0.8930
# Epoch 53/75
# 118/118 [==============================] - 2s 14ms/step - loss: 0.2697 - accuracy: 0.9163 - val_loss: 0.3596 - val_accuracy: 0.8907
# Epoch 54/75
# 118/118 [==============================] - 2s 17ms/step - loss: 0.2666 - accuracy: 0.9177 - val_loss: 0.3582 - val_accuracy: 0.8926
# Epoch 55/75
# 118/118 [==============================] - 2s 14ms/step - loss: 0.2692 - accuracy: 0.9168 - val_loss: 0.3632 - val_accuracy: 0.8876
# Epoch 56/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2657 - accuracy: 0.9177 - val_loss: 0.3612 - val_accuracy: 0.8914
# Epoch 57/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2670 - accuracy: 0.9185 - val_loss: 0.3638 - val_accuracy: 0.8901
# Epoch 58/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2650 - accuracy: 0.9175 - val_loss: 0.3552 - val_accuracy: 0.8915
# Epoch 59/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2650 - accuracy: 0.9174 - val_loss: 0.3522 - val_accuracy: 0.8931
# Epoch 60/75
# 118/118 [==============================] - 1s 12ms/step - loss: 0.2653 - accuracy: 0.9171 - val_loss: 0.3542 - val_accuracy: 0.8938
# Epoch 61/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2640 - accuracy: 0.9183 - val_loss: 0.3617 - val_accuracy: 0.8894
# Epoch 62/75
# 118/118 [==============================] - 1s 12ms/step - loss: 0.2626 - accuracy: 0.9187 - val_loss: 0.3562 - val_accuracy: 0.8898
# Epoch 63/75
# 118/118 [==============================] - 2s 17ms/step - loss: 0.2624 - accuracy: 0.9184 - val_loss: 0.3585 - val_accuracy: 0.8911
# Epoch 64/75
# 118/118 [==============================] - 2s 17ms/step - loss: 0.2619 - accuracy: 0.9188 - val_loss: 0.3511 - val_accuracy: 0.8910
# Epoch 65/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2640 - accuracy: 0.9196 - val_loss: 0.3486 - val_accuracy: 0.8954
# Epoch 66/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2659 - accuracy: 0.9185 - val_loss: 0.3661 - val_accuracy: 0.8892
# Epoch 67/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2569 - accuracy: 0.9218 - val_loss: 0.3649 - val_accuracy: 0.8934
# Epoch 68/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2603 - accuracy: 0.9194 - val_loss: 0.3644 - val_accuracy: 0.8929
# Epoch 69/75
# 118/118 [==============================] - 1s 12ms/step - loss: 0.2617 - accuracy: 0.9178 - val_loss: 0.3676 - val_accuracy: 0.8900
# Epoch 70/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2588 - accuracy: 0.9210 - val_loss: 0.3602 - val_accuracy: 0.8915
# Epoch 71/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2547 - accuracy: 0.9227 - val_loss: 0.3595 - val_accuracy: 0.8919
# Epoch 72/75
# 118/118 [==============================] - 2s 15ms/step - loss: 0.2560 - accuracy: 0.9216 - val_loss: 0.3675 - val_accuracy: 0.8890
# Epoch 73/75
# 118/118 [==============================] - 2s 17ms/step - loss: 0.2553 - accuracy: 0.9217 - val_loss: 0.3568 - val_accuracy: 0.8922
# Epoch 74/75
# 118/118 [==============================] - 2s 14ms/step - loss: 0.2621 - accuracy: 0.9180 - val_loss: 0.3622 - val_accuracy: 0.8927
# Epoch 75/75
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2533 - accuracy: 0.9233 - val_loss: 0.3539 - val_accuracy: 0.8925
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3539 - accuracy: 0.8925
#
# Точність на тестовому наборі: 0.89

# %% [markdown]
# ## Візуалізація кривих навчання

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

ax1.plot(history.history['val_loss'], label='Validation Loss', marker='o', color='r')
ax1.plot(history.history['loss'], label='Loss', color='r', alpha=0.5)
ax1.set_ylabel('Loss Function', color='b')
ax1.tick_params(axis='y', labelcolor='b')

ax2 = ax1.twinx()

ax2.plot(history.history['val_accuracy'], label='Validation Accuracy',  marker='o', color='b')
ax2.plot(history.history['accuracy'], label='Accuracy', color='b', alpha=0.5)

for i, acc in enumerate(history.history['val_accuracy']):
    ax2.annotate(f'{acc:.2f}', (i, acc), textcoords="offset points", xytext=(0, -15), ha='center', c='b', fontsize=6)
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy', color='r')
ax2.tick_params(axis='y', labelcolor='r')
ax1.grid(True, linestyle='--')

ax1.legend(loc='upper left')
ax2.legend(loc='lower right')

plt.title('Криві навчання')

plt.show()

# %% [markdown]
# # Перевірка моделі

# %%
predictions = model.predict(x_test)
number_of_images = 40
f, ax = plt.subplots(5, 8, figsize=(16, 10))
f.subplots_adjust(hspace=0.5, wspace=0.3)

f.suptitle("Візуалізація передбачень моделі для датасета", fontsize=14)


for axes_index, sample_index in enumerate(np.random.choice(10000, number_of_images)):
    prob = predictions[sample_index]
    img, true_label = x_test[sample_index], y_test[sample_index]
    predicted_label = np.argmax(prob)
    if predicted_label == true_label:
        color = 'green'
        cmap = 'Greens'
    else:
        color = 'red'
        cmap = 'Reds'

    ax[axes_index//8, axes_index % 8].imshow(img, cmap=cmap)
    ax[axes_index//8, axes_index % 8].axis('off')
    ax[axes_index//8, axes_index %
        8].set_title(f"Pred: {predicted_label} - {class_labels.get(predicted_label)}\nTrue: {true_label} - {class_labels.get(true_label)}\nProb: {prob.max()*100:.0f} %", fontsize=8, color=color)

    inset_ax = f.add_axes([ax[axes_index//8, axes_index % 8].get_position().x1, ax[axes_index//8, axes_index % 8].get_position().y0, 0.02, ax[axes_index//8, axes_index % 8].get_position().height])

    classes = np.arange(len(class_labels))
    inset_ax.scatter(np.ones(10)*0.5,
                     classes,
                     s=20,
                     c=prob,
                     cmap='Reds',
                     marker='o',
                     edgecolor=(0.5, 0.5, 0.5, 0.2),
                     linewidths=1,
                     )
    inset_ax.set_xlim(0, 1)
    inset_ax.set_ylim(-1, 10)
    inset_ax.set_xticks([])
    inset_ax.set_yticks([])
    inset_ax.axis('off')
    for i, p in enumerate(prob):
        if p > 0.1:
            inset_ax.text(0.7, i, f'{i}', fontsize=8, verticalalignment='center')

plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step
